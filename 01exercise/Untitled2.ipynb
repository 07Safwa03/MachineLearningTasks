# %% [markdown]
# <a href="https://colab.research.google.com/github/07Safwa03/MachineLearningTasks/blob/main/01exercise/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
# Misalkan dataset Anda bernama 'gizi.excel'
import pandas as pd
gizi = pd.read_excel('/content/gizi2023.xlsx')

# %%
# Cek apakah ada nilai NaN
print(gizi.isna().sum())
# Out:
# Tahun                     0
# Tahun (usia saat ukur)    0
# Tinggi                    0
# ZS TB/U                   0
# TB/U                      0
# dtype: int64

# %%
gizi.dropna(inplace=True)  # Menghapus baris yang mengandung NaN

# %%
# Cek apakah ada nilai NaN
print(gizi.isna().sum())
# Out:
# Tahun                     0
# Tahun (usia saat ukur)    0
# Tinggi                    0
# ZS TB/U                   0
# TB/U                      0
# dtype: int64

# %%
# Pastikan data tidak kosong
print(X_train.shape)
print(y_train.shape)
# Out:
# (1420, 4)
# (1420,)

# %% [markdown]
# Load the gizi dataset

# %%
# Muat dataset status gizi

X = gizi.drop(columns=['TB/U'])  # Ganti 'Target' dengan nama kolom target
y = gizi['TB/U']

# %%
X.shape
# Out:
# (1775, 4)

# %%
X
# Out:
#       Tahun  Tahun (usia saat ukur)  Tinggi  ZS TB/U
# 0         1                    0.39    67.0     1.57
# 1         2                    0.63    67.0    -1.44
# 2         2                    0.74    67.0    -2.23
# 3         1                    0.51    68.0    -1.68
# 4         2                    0.63    69.0    -0.51
# ...     ...                     ...     ...      ...
# 1770      2                    0.00    49.0    -1.20
# 1771      1                    0.00    49.0    -1.23
# 1772      2                    0.00    49.0    -2.41
# 1773      1                    0.00    49.0    -0.08
# 1774      1                    0.00    49.0    -0.08
#
# [1775 rows x 4 columns]

# %%
y.shape
# Out:
# (1775,)

# %%
y
# Out:
# 0       Normal
# 1       Normal
# 2       Pendek
# 3       Normal
# 4       Normal
#          ...
# 1770    Normal
# 1771    Normal
# 1772    Pendek
# 1773    Normal
# 1774    Normal
# Name: TB/U, Length: 1775, dtype: object

# %% [markdown]
# terget_names

# %%
gizi['TB/U']
# Out:
# 0       Normal
# 1       Normal
# 2       Pendek
# 3       Normal
# 4       Normal
#          ...
# 1770    Normal
# 1771    Normal
# 1772    Pendek
# 1773    Normal
# 1774    Normal
# Name: TB/U, Length: 1775, dtype: object

# %% [markdown]
# view some iris data at the beginning and end

# %%
import pandas as pd
# Membuat DataFrame dari dataset Iris
gizi = pd.DataFrame({"Tahun": gizi["Tahun"], "ZS_TB/U": gizi["ZS TB/U"]})


# Menampilkan Dimensi DataFrame Iris
gizi.shape
# Out:
# (1775, 2)

# %%
import pandas as pd
#Membaca Data
gizi = pd.read_excel('/content/gizi2023.xlsx')
gizi.head()
# Out:
#    Tahun  Tahun (usia saat ukur)  Tinggi  ZS TB/U    TB/U
# 0      1                    0.39    67.0     1.57  Normal
# 1      2                    0.63    67.0    -1.44  Normal
# 2      2                    0.74    67.0    -2.23  Pendek
# 3      1                    0.51    68.0    -1.68  Normal
# 4      2                    0.63    69.0    -0.51  Normal

# %%
#mengetahui type setiap atribut
gizi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1775 entries, 0 to 1774
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Tahun                   1775 non-null   int64
#  1   Tahun (usia saat ukur)  1775 non-null   float64
#  2   Tinggi                  1775 non-null   float64
#  3   ZS TB/U                 1775 non-null   float64
#  4   TB/U                    1775 non-null   object
# dtypes: float64(3), int64(1), object(1)
# memory usage: 69.5+ KB

# %%
#mengecek apakah ada data kosong
dataset.empty
# Out:
# False

# %%
gizi.head()
# Out:
#    Tahun  Tahun (usia saat ukur)  Tinggi  ZS TB/U    TB/U
# 0      1                    0.39    67.0     1.57  Normal
# 1      2                    0.63    67.0    -1.44  Normal
# 2      2                    0.74    67.0    -2.23  Pendek
# 3      1                    0.51    68.0    -1.68  Normal
# 4      2                    0.63    69.0    -0.51  Normal

# %%
gizi.tail()
# Out:
#       Tahun  Tahun (usia saat ukur)  Tinggi  ZS TB/U    TB/U
# 1770      2                     0.0    49.0    -1.20  Normal
# 1771      1                     0.0    49.0    -1.23  Normal
# 1772      2                     0.0    49.0    -2.41  Pendek
# 1773      1                     0.0    49.0    -0.08  Normal
# 1774      1                     0.0    49.0    -0.08  Normal

# %%
gizi
# Out:
#       Tahun  Tahun (usia saat ukur)  Tinggi  ZS TB/U    TB/U
# 0         1                    0.39    67.0     1.57  Normal
# 1         2                    0.63    67.0    -1.44  Normal
# 2         2                    0.74    67.0    -2.23  Pendek
# 3         1                    0.51    68.0    -1.68  Normal
# 4         2                    0.63    69.0    -0.51  Normal
# ...     ...                     ...     ...      ...     ...
# 1770      2                    0.00    49.0    -1.20  Normal
# 1771      1                    0.00    49.0    -1.23  Normal
# 1772      2                    0.00    49.0    -2.41  Pendek
# 1773      1                    0.00    49.0    -0.08  Normal
# 1774      1                    0.00    49.0    -0.08  Normal
#
# [1775 rows x 5 columns]

# %% [markdown]
# statistik deskriptif

# %%
gizi.describe()
# Out:
#              Tahun  Tahun (usia saat ukur)       Tinggi      ZS TB/U
# count  1775.000000             1775.000000  1775.000000  1775.000000
# mean      1.520563                2.717842    88.086761    -0.832141
# std       0.499718                1.336841    12.596863     1.342986
# min       1.000000                0.000000    48.000000    -9.440000
# 25%       1.000000                1.620000    80.050000    -1.570000
# 50%       2.000000                2.800000    90.000000    -1.000000
# 75%       2.000000                3.850000    97.450000    -0.290000
# max       2.000000                5.590000   116.900000    17.970000

# %% [markdown]
# Divide the data into training and test data

# %%
# Bagi data menjadi data pelatihan (80%) dan data uji (20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
X_train.shape
# Out:
# (1420, 4)

# %%
X_train
# Out:
#       Tahun  Tahun (usia saat ukur)  Tinggi  ZS TB/U
# 1407      2                    1.73    79.0    -2.11
# 148       2                    4.80   104.7    -0.88
# 674       1                    1.89    85.0    -0.13
# 1506      1                    2.81    89.5    -1.08
# 150       1                    3.67   106.0     1.35
# ...     ...                     ...     ...      ...
# 1122      1                    2.21    88.0    -0.44
# 1346      1                    0.32    59.5    -1.11
# 1406      1                    1.82    79.0    -1.81
# 1389      1                    1.30    76.5    -0.60
# 1534      2                    3.10    92.5    -1.17
#
# [1420 rows x 4 columns]

# %%
X_test.shape
# Out:
# (355, 4)

# %%
X_test
# Out:
#       Tahun  Tahun (usia saat ukur)  Tinggi  ZS TB/U
# 252       1                    2.67    91.0    -0.37
# 831       1                    1.50    76.0    -1.66
# 384       1                    1.28    75.0    -1.08
# 1156      2                    4.54    98.5    -1.91
# 189       1                    1.27    76.0    -0.66
# ...     ...                     ...     ...      ...
# 204       2                    1.43    80.0    -0.58
# 1189      1                    2.63    84.0    -2.21
# 683       2                    2.28    87.0    -0.89
# 332       1                    4.76   100.8     1.94
# 1331      2                    3.87   101.0    -0.37
#
# [355 rows x 4 columns]

# %%
y_train.shape
# Out:
# (1420,)

# %%
y_train
# Out:
# 1407    Pendek
# 148     Normal
# 674     Normal
# 1506    Normal
# 150     Normal
#          ...
# 1122    Normal
# 1346    Normal
# 1406    Normal
# 1389    Normal
# 1534    Normal
# Name: TB/U, Length: 1420, dtype: object

# %%
y_test.shape
# Out:
# (355,)

# %%
y_test
# Out:
# 252     Normal
# 831     Normal
# 384     Normal
# 1156    Normal
# 189     Normal
#          ...
# 204     Normal
# 1189    Pendek
# 683     Normal
# 332     Normal
# 1331    Normal
# Name: TB/U, Length: 355, dtype: object

# %% [markdown]
# Naive Bayes model initialization

# %%
# Inisialisasi model Naive Bayes
naive_bayes_model = GaussianNB()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
X_train_encoded = X_train.apply(le.fit_transform)

# %%
from sklearn.preprocessing import LabelEncoder

# Encode categorical features

en = LabelEncoder()

gizi['Tahun'] = en.fit_transform(gizi['Tahun'])
gizi.head()
# Out:
#    Tahun  Tahun (usia saat ukur)  Tinggi  ZS TB/U    TB/U
# 0      0                    0.39    67.0     1.57  Normal
# 1      1                    0.63    67.0    -1.44  Normal
# 2      1                    0.74    67.0    -2.23  Pendek
# 3      0                    0.51    68.0    -1.68  Normal
# 4      1                    0.63    69.0    -0.51  Normal

# %% [markdown]
# Train the model with training data

# %%
# Latih model dengan data pelatihan
naive_bayes_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# Perform prediction on test data

# %%
# Lakukan prediksi pada data uji
y_pred = naive_bayes_model.predict(X_test)

# %%
y_pred.shape
# Out:
# (355,)

# %%
y_pred
# Out:
# array(['Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Pendek', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Pendek', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Pendek', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Sangat Pendek', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Sangat Pendek',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Tinggi',
# ...

# %% [markdown]
# Calculate model accuracy

# %%
# Hitung akurasi model
accuracy = accuracy_score(y_test, y_pred)
print(f'Akurasi: {accuracy}')
# Out:
# Akurasi: 0.9492957746478873

# %% [markdown]
# Classification Report

# %%
print(classification_report(y_test,y_pred))
# Out:
#                precision    recall  f1-score   support
#
#        Normal       0.96      0.99      0.97       325
#        Pendek       1.00      0.48      0.65        23
# Sangat Pendek       0.40      0.40      0.40         5
#        Tinggi       1.00      0.50      0.67         2
#
#      accuracy                           0.95       355
#     macro avg       0.84      0.59      0.67       355
#  weighted avg       0.95      0.95      0.94       355

# %% [markdown]
# Confusion Matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Hitung confusion matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[323,   0,   2,   0],
#        [ 12,  11,   0,   0],
#        [  3,   0,   2,   0],
#        [  0,   0,   1,   1]])

# %%
# Tampilkan confusion matrix dengan heatmap menggunakan seaborn
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=gizi['TB/U'], yticklabels=gizi['TB/U'])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Menyesuaikan ukuran gambar
sns.barplot(x=gizi['Tahun (usia saat ukur)'], y=gizi['TB/U'],
            hue=gizi['TB/U'], palette="viridis")

plt.title("Tinggi Badan/U Berdasarkan Usia dan Kategori Gizi", fontsize=16)
plt.xlabel("Tahun (Usia Saat Ukur)", fontsize=14)
plt.ylabel("Tinggi Badan/U", fontsize=14)
plt.legend(title="Kategori Gizi", fontsize=12, title_fontsize='13')

plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Menyesuaikan ukuran gambar
plt.scatter(gizi['Tahun (usia saat ukur)'], gizi['TB/U'],
            c='blue', s=100, edgecolor='k', alpha=0.7)  # Mengatur warna, ukuran, dan transparansi

plt.title("Hubungan Tinggi Badan/U dengan Tahun (Usia Saat Ukur)", fontsize=16)
plt.xlabel("Tahun (Usia Saat Ukur)", fontsize=14)
plt.ylabel("Tinggi Badan/U", fontsize=14)

plt.grid(True)  # Menambahkan grid
plt.show()

# %%
# Tampilkan confusion matrix dengan heatmap menggunakan seaborn
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=gizi['TB/U'], yticklabels=gizi['TB/U'])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
from sklearn.metrics import precision_score

# Menghitung precision untuk setiap kelas
precision_values=precision_score(y_test, y_pred, average=None)
precision_values
# Out:
# array([0.9556213, 1.       , 0.4      , 1.       ])

# %%
# Nama kelas untuk dataset Iris
class_names = iris.target_names

# Membuat plot
plt.figure(figsize=(5, 3))
plt.bar(class_names, precision_values, color='blue')
plt.title('Precision for Each Class (Iris Dataset)')
plt.xlabel('Class')
plt.ylabel('Precision')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-379-96a8c6a9369d> in <cell line: 2>()
#       1 # Nama kelas untuk dataset Iris
# ----> 2 gizi2023.xlsx= gizi2023.xlsx.TB/U
#       3
#       4 # Membuat plot
#       5 plt.figure(figsize=(5, 3))
#
# NameError: name 'gizi2023' is not defined

# %%
from sklearn.metrics import recall_score
recall_values=recall_score(y_test, y_pred, average=None)
recall_values
# Out:
# array([0.99384615, 0.47826087, 0.4       , 0.5       ])
