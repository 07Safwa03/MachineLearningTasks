# %% [markdown]
# <a href="https://colab.research.google.com/github/07Safwa03/MachineLearningTasks/blob/main/01exercise/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np

# %%
dataset = pd.read_excel('/content/DAFTAR BALITA TAHUN 2023 BULAN AGUSTUS - Copy.xls')
dataset.head()
# Out:
#      No                       Nama  JK    Tgl Lahir BB Lahir TB Lahir  \
# 0    1.          OLIVIA AVANTIAKA   P   2023-03-20        3       49
# 1  2 .   ARSHAKA ZAYYAN KEENANDRA   L   2022-12-20      3.5       49
# 2  3 .            WISAKA GANENDRA   L   2022-11-15      2.9       49
# 3  4 .    NAYSILLA RISQIANA PUTRI   P   2023-02-03      2.7       49
# 4  5 .      ARSYAKA BRYAN ALFATIH   L   2022-12-21        3       49
#
#                 Nama Ortu         Prov    Kab/Kota        Kec  ... ZS BB/U  \
# 0            SUNITA DEWI   JAWA TIMUR   KAB NGAWI   JOGOROGO   ...    0.49
# 1         ERNA RATNASARI   JAWA TIMUR   KAB NGAWI   JOGOROGO   ...   -0.35
# 2        RINI SUSILOWATI   JAWA TIMUR   KAB NGAWI   JOGOROGO   ...   -0.33
# 3               NUROHMAH   JAWA TIMUR   KAB NGAWI   JOGOROGO   ...   -2.53
# 4  LISNA ARDILA IKE DEWI   JAWA TIMUR   KAB NGAWI   JOGOROGO   ...   -0.91
#
#      TB/U ZS TB/U                BB/TB  ZS BB/TB Naik Berat Badan  \
# ...

# %%
plt.xlabel('Desa/Kel')
plt.ylabel('Jumlah Desa/Kel')
plt.title("Distribusi Desa/Kel")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
