# %% [markdown]
# <a href="https://colab.research.google.com/github/07Safwa03/MachineLearningTasks/blob/main/01exercise/Gizi2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Persiapan Data

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#mengimport data dari excel dan memberi keterangan pada variabel x dan y
gizi = pd.read_excel('/content/gizi2023.xlsx', sheet_name='Sheet1')
x = gizi.iloc[:, [2, 3]].values
y = gizi.iloc[:, -1]

# %%
print (x)
# Out:
# [[67.    1.57]
#  [67.   -1.44]
#  [67.   -2.23]
#  ...
#  [49.   -2.41]
#  [49.   -0.08]
#  [49.   -0.08]]

# %%
print (y)
# Out:
# 0       Normal
# 1       Normal
# 2       Pendek
# 3       Normal
# 4       Normal
#          ...
# 1770    Normal
# 1771    Normal
# 1772    Pendek
# 1773    Normal
# 1774    Normal
# Name: TB/U, Length: 1775, dtype: object

# %% [markdown]
# load dataset

# %%
#menjelaskan berapa isi dari isi X berapa
x.shape
# Out:
# (1775, 2)

# %%
x
# Out:
# array([[67.  ,  1.57],
#        [67.  , -1.44],
#        [67.  , -2.23],
#        ...,
#        [49.  , -2.41],
#        [49.  , -0.08],
#        [49.  , -0.08]])

# %%
#menjelaskan berapa isi dari variabel y berapa
y.shape
# Out:
# (1775,)

# %%
y
# Out:
# 0       Normal
# 1       Normal
# 2       Pendek
# 3       Normal
# 4       Normal
#          ...
# 1770    Normal
# 1771    Normal
# 1772    Pendek
# 1773    Normal
# 1774    Normal
# Name: TB/U, Length: 1775, dtype: object

# %% [markdown]
# meneliti isi dataset

# %%
#Menampilkan 5 Data teratas
gizi.head()
# Out:
#    Jenis Kelamin  Tahun (usia saat ukur)  Tinggi  ZS TB/U    TB/U
# 0              1                    0.39    67.0     1.57  Normal
# 1              2                    0.63    67.0    -1.44  Normal
# 2              2                    0.74    67.0    -2.23  Pendek
# 3              1                    0.51    68.0    -1.68  Normal
# 4              2                    0.63    69.0    -0.51  Normal

# %%
#Menampilkan 5 Data terakhir
gizi.tail()
# Out:
#       Jenis Kelamin  Tahun (usia saat ukur)  Tinggi  ZS TB/U    TB/U
# 1770              2                     0.0    49.0    -1.20  Normal
# 1771              1                     0.0    49.0    -1.23  Normal
# 1772              2                     0.0    49.0    -2.41  Pendek
# 1773              1                     0.0    49.0    -0.08  Normal
# 1774              1                     0.0    49.0    -0.08  Normal

# %%
#Menampilkan seluruh jumlah Dataset
gizi
# Out:
#       Jenis Kelamin  Tahun (usia saat ukur)  Tinggi  ZS TB/U    TB/U
# 0                 1                    0.39    67.0     1.57  Normal
# 1                 2                    0.63    67.0    -1.44  Normal
# 2                 2                    0.74    67.0    -2.23  Pendek
# 3                 1                    0.51    68.0    -1.68  Normal
# 4                 2                    0.63    69.0    -0.51  Normal
# ...             ...                     ...     ...      ...     ...
# 1770              2                    0.00    49.0    -1.20  Normal
# 1771              1                    0.00    49.0    -1.23  Normal
# 1772              2                    0.00    49.0    -2.41  Pendek
# 1773              1                    0.00    49.0    -0.08  Normal
# 1774              1                    0.00    49.0    -0.08  Normal
#
# [1775 rows x 5 columns]

# %% [markdown]
# Pra-Pemrosesan Data

# %%
#Statistic deskriptif
gizi.describe()
# Out:
#        Jenis Kelamin  Tahun (usia saat ukur)       Tinggi      ZS TB/U
# count    1775.000000             1775.000000  1775.000000  1775.000000
# mean        1.520563                2.717842    88.086761    -0.832141
# std         0.499718                1.336841    12.596863     1.342986
# min         1.000000                0.000000    48.000000    -9.440000
# 25%         1.000000                1.620000    80.050000    -1.570000
# 50%         2.000000                2.800000    90.000000    -1.000000
# 75%         2.000000                3.850000    97.450000    -0.290000
# max         2.000000                5.590000   116.900000    17.970000

# %%
# Cek apakah ada nilai NaN
print(gizi.isna().sum())
# Out:
# Jenis Kelamin             0
# Tahun (usia saat ukur)    0
# Tinggi                    0
# ZS TB/U                   0
# TB/U                      0
# dtype: int64

# %%
#mengecek apakah ada data kosong
gizi.empty
# Out:
# False

# %% [markdown]
# Membagi Data untuk Pelatihan dan Pengujian

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (1420, 2)

# %%
x_train
# Out:
# array([[99.  , -2.01],
#        [77.8 , -1.39],
#        [74.  , -0.4 ],
#        ...,
#        [89.  , -1.82],
#        [84.8 , -2.71],
#        [89.  , -0.46]])

# %%
x_test.shape
# Out:
# (355, 2)

# %%
x_test
# Out:
# array([[ 8.570e+01, -1.910e+00],
#        [ 8.020e+01, -1.640e+00],
#        [ 9.670e+01, -1.480e+00],
#        [ 1.010e+02, -2.200e-01],
#        [ 9.480e+01, -1.480e+00],
#        [ 1.020e+02, -1.670e+00],
#        [ 8.720e+01, -1.260e+00],
#        [ 9.900e+01,  6.600e-01],
#        [ 8.120e+01, -2.620e+00],
#        [ 1.075e+02, -3.400e-01],
#        [ 9.900e+01, -1.480e+00],
#        [ 8.750e+01, -3.300e-01],
#        [ 1.067e+02, -5.600e-01],
#        [ 9.550e+01, -5.700e-01],
#        [ 9.800e+01, -1.750e+00],
#        [ 9.450e+01, -8.800e-01],
#        [ 9.590e+01, -1.800e-01],
#        [ 9.050e+01, -4.600e-01],
#        [ 9.400e+01, -1.560e+00],
#        [ 9.450e+01, -1.960e+00],
#        [ 1.030e+02, -1.240e+00],
#        [ 4.900e+01, -4.700e-01],
#        [ 8.400e+01,  4.800e-01],
#        [ 9.500e+01,  4.230e+00],
#        [ 1.030e+02, -1.240e+00],
#        [ 9.400e+01, -1.030e+00],
#        [ 9.430e+01, -1.340e+00],
#        [ 8.400e+01, -1.770e+00],
# ...

# %%
y_train.shape
# Out:
# (1420,)

# %%
y_train
# Out:
# 1040    Pendek
# 198     Normal
# 15      Normal
# 265     Normal
# 817     Normal
#          ...
# 1130    Normal
# 1294    Normal
# 860     Normal
# 1459    Pendek
# 1126    Normal
# Name: TB/U, Length: 1420, dtype: object

# %%
#Menstandarisasi atau Normalisasi Data:
from sklearn.preprocessing import StandardScaler
sc = StandardScaler ()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
print (x_train)
# Out:
# [[ 0.86783178 -0.87613364]
#  [-0.81939628 -0.40501234]
#  [-1.12182395  0.34726199]
#  ...
#  [ 0.07196949 -0.73175776]
#  [-0.26229267 -1.40804478]
#  [ 0.07196949  0.3016696 ]]

# %%
print (x_test)
# Out:
# [[-1.85030647e-01 -8.17665705e-01]
#  [-6.17899493e-01 -6.30142956e-01]
#  [ 6.80707044e-01 -5.19018364e-01]
#  [ 1.01913178e+00  3.56087800e-01]
#  [ 5.31170534e-01 -5.19018364e-01]
#  [ 1.09783520e+00 -6.50978817e-01]
#  [-6.69755075e-02 -3.66222050e-01]
#  [ 8.61724925e-01  9.67273057e-01]
#  [-5.39196067e-01 -1.31078108e+00]
#  [ 1.53070405e+00  2.72744356e-01]
#  [ 8.61724925e-01 -5.19018364e-01]
#  [-4.33644795e-02  2.79689643e-01]
#  [ 1.46774131e+00  1.19948041e-01]
#  [ 5.86262933e-01  1.13002754e-01]
#  [ 7.83021499e-01 -7.06541113e-01]
#  [ 5.07559506e-01 -1.02301143e-01]
#  [ 6.17744303e-01  3.83868948e-01]
#  [ 1.92745800e-01  1.89400911e-01]
#  [ 4.68207793e-01 -5.74580660e-01]
#  [ 5.07559506e-01 -8.52392140e-01]
#  [ 1.17653863e+00 -3.52331476e-01]
#  [-3.07344640e+00  1.82455624e-01]
#  [-3.18826472e-01  8.42257891e-01]
#  [ 5.46911219e-01  3.44674052e+00]
#  [ 1.17653863e+00 -3.52331476e-01]
#  [ 4.68207793e-01 -2.06480448e-01]
#  [ 4.91818821e-01 -4.21784346e-01]
# ...

# %% [markdown]
# Membangun dan Melatih Model

# %%
# Inisialisasi model Naive Bayes
Classifier = GaussianNB()

# %%
# Latih model dengan data pelatihan
Classifier.fit(x_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# Menyimpan dan Memuat Model

# %%
# Lakukan prediksi pada data uji
y_pred = Classifier.predict(x_test)

# %%
y_pred.shape
# Out:
# (355,)

# %%
y_pred
# Out:
# array(['Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Pendek', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Tinggi',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Sangat Pendek', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Pendek', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Pendek', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Hitung confusion matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[319,   0,   0,   0],
#        [ 12,  14,   0,   0],
#        [  4,   0,   2,   1],
#        [  0,   0,   0,   3]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#                precision    recall  f1-score   support
#
#        Normal       0.95      1.00      0.98       319
#        Pendek       1.00      0.54      0.70        26
# Sangat Pendek       1.00      0.29      0.44         7
#        Tinggi       0.75      1.00      0.86         3
#
#      accuracy                           0.95       355
#     macro avg       0.93      0.71      0.74       355
#  weighted avg       0.95      0.95      0.94       355

# %%
# Hitung akurasi model
accuracy = accuracy_score(y_test, y_pred)
print(f'Akurasi: {accuracy}')
# Out:
# Akurasi: 0.952112676056338

# %%
# 2. Misalkan kolom 'actual' adalah label sebenarnya dan kolom 'predicted' adalah prediksi model
y_test = gizi #label sebenarnya dari data test
y_pred = gizi #Label sebenarnya model pada data test

# %%
# 4. Visualisasi Confusion Matrix
plt.figure(figsize=(5, 3))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('y_pred')
plt.ylabel('y_test')
plt.title(' Confusion Matrix 2023')
plt.show()

# %%
plt.figure(figsize=(5, 3))  # Menyesuaikan ukuran gambar

# Menggunakan histogram
plt.hist(gizi['Tahun (usia saat ukur)'], bins=5, color='orange', edgecolor='black', alpha=0.7)

plt.title("Distribusi Tinggi Badan/U", fontsize=16)
plt.xlabel("Tahun (usia saat ukur)", fontsize=14)
plt.ylabel("TB/U", fontsize=14)

plt.grid(True)  # Menambahkan grid
plt.show()

# %%
# Buat plot
plt.figure(figsize=(5, 3))  # Menyesuaikan ukuran gambar

# Mengubah warna menjadi merah
plt.scatter(gizi['Jenis Kelamin'], gizi['Tinggi'],
            c=(0.2, 0.4, 0.6), s=100, edgecolor='k', alpha=0.7)  # Warna RGB
plt.colorbar(label='TB/U')  # Menambahkan colorbar

plt.title("Hubungan Tinggi Badan/U dengan Tahun (Usia Saat Ukur)", fontsize=16)
plt.xlabel("Jenis Kelamin", fontsize=14)
plt.ylabel("Tinggi", fontsize=14)

plt.grid(True)  # Menambahkan grid
plt.show()
# Out:
# <ipython-input-53-9a76ecc4a8a0>:5: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(gizi['Jenis Kelamin'], gizi['Tinggi'],

# %%
# Buat plot
plt.figure(figsize=(5, 3))  # Menyesuaikan ukuran gambar

# Mengubah warna menjadi merah
plt.scatter(gizi['ZS TB/U'], gizi['TB/U'],
            c=(0.2, 0.4, 0.6), s=100, edgecolor='k', alpha=0.7)  # Warna RGB
plt.colorbar(label='TB/U')  # Menambahkan colorbar

plt.title("Hubungan Tinggi Badan/U dengan Tahun (Usia Saat Ukur)", fontsize=16)
plt.xlabel("ZS TB/U", fontsize=14)
plt.ylabel("TB/U", fontsize=14)

plt.grid(True)  # Menambahkan grid
plt.show()
# Out:
# <ipython-input-54-590b5dccbf13>:5: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(gizi['ZS TB/U'], gizi['TB/U'],
