# %% [markdown]
# <a href="https://colab.research.google.com/github/07Safwa03/MachineLearningTasks/blob/main/01exercise/projek%20skripsiTBU2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Persiapan Data

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# Membaca file Excel ke dalam DataFrame
df = pd.read_excel('/content/TBU2023.xlsx')

# Membuat diagram frekuensi menggunakan Seaborn
print(df.head())
# Out:
#   Jk  Umur  Tinggi  ZS TB/U    TB/U
# 0  P  0.39    67.0     1.57  Normal
# 1  L  0.63    67.0    -1.44  Normal
# 2  L  0.74    67.0    -2.23  Pendek
# 3  P  0.51    68.0    -1.68  Normal
# 4  L  0.63    69.0    -0.51  Normal

# %%
# Menampilkan nama kolom untuk verifikasi
print(df.columns)
# Out:
# Index(['Jk', 'Umur', 'Tinggi', 'ZS TB/U', 'TB/U'], dtype='object')

# %%
# Hitung frekuensi kategori
kategori_counts = df['TB/U'].value_counts()

# Urutkan kategori berdasarkan frekuensi dari yang tertinggi ke terendah
kategori_sorted = kategori_counts.sort_values(ascending=False)

# Plot histogram berdasarkan urutan frekuensi
plt.bar(kategori_sorted.index, kategori_sorted.values, color='blue', edgecolor='black')

plt.xlabel('Kategori TB/U')
plt.ylabel('Frekuensi')
plt.title('Histogram Distribusi Data Tinggi dan TB/U Tahun 2023')
plt.xticks(rotation=45)  # Memutar label agar lebih mudah dibaca
plt.show()

# %%
#mengimport data dari excel dan memberi keterangan pada variabel x dan y
gizi = pd.read_excel('/content/TBU2023.xlsx', sheet_name='Sheet1')
x = gizi.iloc[:, [ 1, 2, 3]].values
y = gizi.iloc[:, -1]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Membuat scatter plot
plt.scatter(df['Umur'], df['Tinggi'])
plt.xlabel('Umur')
plt.ylabel('Tinggi badan')
plt.title('Hubungan antara Umur dan tinggi data 2023')
plt.show()

# %%
print (x)
# Out:
# [[ 0.39 67.    1.57]
#  [ 0.63 67.   -1.44]
#  [ 0.74 67.   -2.23]
#  ...
#  [ 0.   49.   -2.41]
#  [ 0.   49.   -0.08]
#  [ 0.   49.   -0.08]]

# %%
print (y)
# Out:
# 0       Normal
# 1       Normal
# 2       Pendek
# 3       Normal
# 4       Normal
#          ...
# 1770    Normal
# 1771    Normal
# 1772    Pendek
# 1773    Normal
# 1774    Normal
# Name: TB/U, Length: 1775, dtype: object

# %% [markdown]
# Load Dataset

# %%
#menjelaskan berapa isi dari isi X berapa
x.shape
# Out:
# (1775, 3)

# %%
x
# Out:
# array([[ 0.39, 67.  ,  1.57],
#        [ 0.63, 67.  , -1.44],
#        [ 0.74, 67.  , -2.23],
#        ...,
#        [ 0.  , 49.  , -2.41],
#        [ 0.  , 49.  , -0.08],
#        [ 0.  , 49.  , -0.08]])

# %%
#menjelaskan berapa isi dari variabel y berapa
y.shape
# Out:
# (1775,)

# %%
y
# Out:
# 0       Normal
# 1       Normal
# 2       Pendek
# 3       Normal
# 4       Normal
#          ...
# 1770    Normal
# 1771    Normal
# 1772    Pendek
# 1773    Normal
# 1774    Normal
# Name: TB/U, Length: 1775, dtype: object

# %% [markdown]
# meneliti dataset

# %%
#Menampilkan 5 Data teratas
gizi.head()
# Out:
#   Jk  Umur  Tinggi  ZS TB/U    TB/U
# 0  P  0.39    67.0     1.57  Normal
# 1  L  0.63    67.0    -1.44  Normal
# 2  L  0.74    67.0    -2.23  Pendek
# 3  P  0.51    68.0    -1.68  Normal
# 4  L  0.63    69.0    -0.51  Normal

# %%
#Menampilkan 5 Data terakhir
gizi.tail()
# Out:
#      Jk  Umur  Tinggi  ZS TB/U    TB/U
# 1770  L   0.0    49.0    -1.20  Normal
# 1771  P   0.0    49.0    -1.23  Normal
# 1772  L   0.0    49.0    -2.41  Pendek
# 1773  P   0.0    49.0    -0.08  Normal
# 1774  P   0.0    49.0    -0.08  Normal

# %%
#Menampilkan seluruh jumlah Dataset
gizi
# Out:
#      Jk  Umur  Tinggi  ZS TB/U    TB/U
# 0     P  0.39    67.0     1.57  Normal
# 1     L  0.63    67.0    -1.44  Normal
# 2     L  0.74    67.0    -2.23  Pendek
# 3     P  0.51    68.0    -1.68  Normal
# 4     L  0.63    69.0    -0.51  Normal
# ...  ..   ...     ...      ...     ...
# 1770  L  0.00    49.0    -1.20  Normal
# 1771  P  0.00    49.0    -1.23  Normal
# 1772  L  0.00    49.0    -2.41  Pendek
# 1773  P  0.00    49.0    -0.08  Normal
# 1774  P  0.00    49.0    -0.08  Normal
#
# [1775 rows x 5 columns]

# %% [markdown]
# pra-pemrosesan data

# %%
#Statistic deskriptif
gizi.describe()
# Out:
#               Umur       Tinggi      ZS TB/U
# count  1775.000000  1775.000000  1775.000000
# mean      2.717842    88.086761    -0.832141
# std       1.336841    12.596863     1.342986
# min       0.000000    48.000000    -9.440000
# 25%       1.620000    80.050000    -1.570000
# 50%       2.800000    90.000000    -1.000000
# 75%       3.850000    97.450000    -0.290000
# max       5.590000   116.900000    17.970000

# %%
# Cek apakah ada nilai NaN
print(gizi.isna().sum())
# Out:
# Jk         0
# Umur       0
# Tinggi     0
# ZS TB/U    0
# TB/U       0
# dtype: int64

# %%
#mengecek apakah ada data kosong
gizi.empty
# Out:
# False

# %% [markdown]
# membagi data untuk pelatihan dan pengujian

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
x_train.shape
# Out:
# (1420, 3)

# %%
x_train
# Out:
# array([[  3.95,  96.  ,  -1.51],
#        [  4.65, 101.6 ,  -1.37],
#        [  4.67, 104.3 ,  -0.67],
#        ...,
#        [  4.53, 101.5 ,  -1.22],
#        [  3.2 ,  95.  ,  -0.7 ],
#        [  2.9 ,  87.5 ,  -0.74]])

# %%
x_test.shape
# Out:
# (355, 3)

# %%
x_test
# Out:
# array([[  1.02,  72.5 ,  -0.7 ],
#        [  4.66,  96.5 ,  -2.34],
#        [  3.87, 104.5 ,   0.48],
#        ...,
#        [  4.62,  98.  ,  -1.96],
#        [  2.32,  84.  ,  -0.91],
#        [  4.11,  96.6 ,  -1.59]])

# %%
y_train.shape
# Out:
# (1420,)

# %%
y_train
# Out:
# 564     Normal
# 1052    Normal
# 1682    Normal
# 379     Normal
# 948     Pendek
#          ...
# 835     Normal
# 1216    Normal
# 1653    Normal
# 559     Normal
# 684     Normal
# Name: TB/U, Length: 1420, dtype: object

# %%
y_test.shape
# Out:
# (355,)

# %%
y_train
# Out:
# 564     Normal
# 1052    Normal
# 1682    Normal
# 379     Normal
# 948     Pendek
#          ...
# 835     Normal
# 1216    Normal
# 1653    Normal
# 559     Normal
# 684     Normal
# Name: TB/U, Length: 1420, dtype: object

# %%
#Menstandarisasi atau Normalisasi Data:
from sklearn.preprocessing import StandardScaler
sc = StandardScaler ()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
print (x_train)
# Out:
# [[ 0.92751826  0.62652736 -0.52064685]
#  [ 1.45109647  1.06875972 -0.41389706]
#  [ 1.46605585  1.28197889  0.11985187]
#  ...
#  [ 1.3613402   1.06086271 -0.29952229]
#  [ 0.36654162  0.54755729  0.09697692]
#  [ 0.14215096 -0.04471819  0.06647698]]

# %%
print (x_test)
# Out:
# [[-1.29637366 -1.27282731  0.10406618]
#  [ 1.43218947  0.67677874 -1.0189612 ]
#  [ 0.84000131  1.32664742  0.91209807]
#  ...
#  [ 1.40220526  0.79862911 -0.75874754]
#  [-0.32188683 -0.33864108 -0.03973611]
#  [ 1.01990658  0.68490209 -0.50538161]]

# %% [markdown]
# membangun danmelatih model

# %%
# Inisialisasi model Naive Bayes
from sklearn.naive_bayes import GaussianNB
Classifier = GaussianNB()

# %%
# Latih model dengan data pelatihan
Classifier.fit(x_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# menyimpan dan memuat model

# %%
# Lakukan prediksi pada data uji
y_pred = Classifier.predict(x_test)

# %%
y_pred.shape
# Out:
# (355,)

# %%
y_pred
# Out:
# array(['Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Pendek',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Pendek', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Pendek', 'Normal', 'Normal',
#        'Pendek', 'Normal', 'Normal', 'Pendek', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Tinggi',
#        'Normal', 'Normal', 'Normal', 'Sangat Pendek', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Hitung confusion matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[305,   0,   1,   0],
#        [ 19,  12,   0,   0],
#        [  3,   3,   4,   1],
#        [  0,   0,   2,   5]])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#                precision    recall  f1-score   support
#
#        Normal       0.93      1.00      0.96       306
#        Pendek       0.80      0.39      0.52        31
# Sangat Pendek       0.57      0.36      0.44        11
#        Tinggi       0.83      0.71      0.77         7
#
#      accuracy                           0.92       355
#     macro avg       0.78      0.62      0.67       355
#  weighted avg       0.91      0.92      0.91       355

# %%
# Hitung akurasi model
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f'Akurasi: {accuracy}')
# Out:
# Akurasi: 0.9183098591549296

# %%
# 4. Visualisasi Confusion Matrix
plt.figure(figsize=(5, 3))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('y_pred')
plt.ylabel('y_test')
plt.title(' Confusion Matrix 2023')
plt.show()

# %%
# prompt: buatkanlah visualisasi data dari klasifikasi diatas

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming 'df' and 'cm' are defined as in the previous code.
# If not, load the data and recalculate the confusion matrix.

# 1. Improved Scatter Plot with Hues
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Umur', y='Tinggi', hue='TB/U', palette='viridis', s=50)
plt.xlabel('Umur')
plt.ylabel('Tinggi Badan')
plt.title('Hubungan Umur, Tinggi Badan, dan Kategori TB/U 2023')
plt.show()

# %%
# 2. Pairplot for Relationships
sns.pairplot(df, hue='TB/U', palette='Set1')
plt.suptitle('Pairplot of Features with TB/U Category', y=1.02)
plt.show()

# %%
# 3. Distribution Plots for each feature
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
sns.histplot(df['Umur'], kde=True, color='skyblue')
plt.title('Distribution of Usia saat Ukur')

plt.subplot(1, 3, 2)
sns.histplot(df['Tinggi'], kde=True, color='salmon')
plt.title('Distribution of Tinggi')

plt.tight_layout()
plt.show()

# %%
# 4. Enhanced Confusion Matrix Visualization
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="viridis", linewidths=.5, cbar_kws={'label': 'Jumlah'})
plt.xlabel('Prediksi')
plt.ylabel('Aktual')
plt.title('Confusion Matrix Klasifikasi TB/U 2023')
plt.show()


# Example of a grouped bar plot (you might need to adjust this based on your data)
plt.figure(figsize=(10, 6))
sns.countplot(x='Umur', hue='TB/U', data=df, palette="Set2")
plt.title('Distribusi Kategori TB/U berdasarkan Tahun')
plt.show()

# %%
# prompt: buatkanlah hasil prediksi klasifikasi naives bayes diatas dengan menggunakan visualisasi data menggunakan digaram scatter plot

import numpy as np
import matplotlib.pyplot as plt

# Assuming 'y_pred' and 'x_test' contain the predictions and corresponding features
# You'll need to adapt this based on how your features are represented.
# For example, if 'x_test' has multiple features, you might choose two relevant ones
# or use dimensionality reduction techniques to visualize in 2D.


# Example assuming 'x_test' has two features (e.g., 'Umur' and 'Tinggi')
# and 'y_pred' has corresponding class predictions

# Extract the features for visualization (replace with actual feature indices)
feature1 = x_test[:, 0]
feature2 = x_test[:, 1]


plt.figure(figsize=(8, 6))
for label in np.unique(y_pred):  # Assuming 'y_pred' is your prediction result
  plt.scatter(feature1[y_pred == label], feature2[y_pred == label], label=f'Predicted Class {label}')

plt.xlabel('Feature 1 (e.g., Umur)')
plt.ylabel('Feature 2 (e.g., Tinggi)')
plt.title('Naive Bayes Classification Predictions 2023')
plt.legend()
plt.show()
