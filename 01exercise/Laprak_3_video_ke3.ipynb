# %% [markdown]
# <a href="https://colab.research.google.com/github/07Safwa03/MachineLearningTasks/blob/main/01exercise/Laprak_3_video_ke3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 1.5.3

# %%
data = {'col1':['1', '2', '3', 'teks'],
        'col2':['1', '2', '3', '4']}

df = pd.DataFrame(data)
df
# Out:
#    col1 col2
# 0     1    1
# 1     2    2
# 2     3    3
# 3  teks    4

# %%
df.dtypes
# Out:
# col1    object
# col2    object
# dtype: object

# %%
#Konversi tipe data dengan fungsi astype()
df_x = df.astype({'col2':'int'})
df_x
# Out:
#    col1  col2
# 0     1     1
# 1     2     2
# 2     3     3
# 3  teks     4

# %%
df_x.dtypes
# Out:
# col1    object
# col2     int64
# dtype: object

# %%
#konversi tipe data numerik dengan fungsi to_numeric()
df.apply(pd.to_numeric, errors='coerce')
# Out:
#    col1  col2
# 0   1.0     1
# 1   2.0     2
# 2   3.0     3
# 3   NaN     4
